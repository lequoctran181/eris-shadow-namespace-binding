# %% [markdown]
# # Shadow Namespace Binding Ledger - CPU Reference
#
# This notebook launches the bundled from-scratch CPU solution.

# %%
from pathlib import Path
import subprocess

dataset_dir = Path('./dataset/public')
working_dir = Path('./working')
working_dir.mkdir(parents=True, exist_ok=True)
subprocess.run([
    'python3', './solution.py', str(dataset_dir),
    str(working_dir / 'submission.csv')
], check=True)
print(working_dir / 'submission.csv')
